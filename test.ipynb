# %%
import os
import mlflow  # <-- that's all you need

# %%
mlflow.set_tracking_uri("https://dagshub.com/kshitij.bhatnagar1579/Kidney-disease-classification.mlflow")

with mlflow.start_run():
    mlflow.log_param("test_param", 123)
    print("✅ Run logged successfully")
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 mlflow.set_tracking_uri("https://dagshub.com/kshitij.bhatnagar1579/Kidney-disease-classification")
# ----> 3 with mlflow.start_run():
#       4     mlflow.log_param("test_param", 123)
#       5     print("✅ Run logged successfully")
#
# File c:\Users\DELL\miniconda3\envs\kidney\lib\site-packages\mlflow\tracking\fluent.py:350, in start_run(run_id, experiment_id, run_name, nested, tags, description)
#     346         user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     348     resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 350     active_run_obj = client.create_run(
#     351         experiment_id=exp_id_for_run, tags=resolved_tags, run_name=run_name
#     352     )
#     354 _active_run_stack.append(ActiveRun(active_run_obj))
#     355 return _active_run_stack[-1]
#
# ...
